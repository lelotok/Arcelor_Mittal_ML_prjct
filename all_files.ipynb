# %%
import pandas as pd 
import glob

# %%
path = "../new_coils_data"
all_files = glob.glob(path + "/*.csv")

# %%
all_files

# %%
n_files = all_files[:100]
n_files

# %%
n_list = [pd.read_csv(filename, index_col=None, header=) for filename in n_files]
n_list
# Out:
# [      Lengthpoints  Values
#  0         0.159637  1252.5
#  1         0.319275  1299.6
#  2         0.478912  1360.8
#  3         0.638605  1373.3
#  4         0.798241  1373.3
#  ...            ...     ...
#  1012    199.022700  1370.9
#  1013    199.228300  1371.0
#  1014    199.434000  1371.0
#  1015    199.639800  1371.1
#  1016    199.845900  1370.9
#
#  [1017 rows x 2 columns],
#       Lengthpoints  Values
#  0        0.267164  1359.8
#  1        0.534553  1359.8
#  2        0.802384  1368.8
#  3        1.070105  1368.2
#  4        1.338273  1367.2
#  ..            ...     ...
#  624    198.436800  1354.3
#  625    198.811400  1354.1
#  626    199.186400  1354.1
#  627    199.561400  1354.1
#  628    199.936500  1354.0
#
#  [629 rows x 2 columns],
#       Lengthpoints  Values
#  0        0.433731  1053.5
#  1        0.867224  1054.0
#  2        1.300909  1055.9
#  3        1.735023  1055.9
#  4        2.169203  1064.1
#  ..            ...     ...
#  432    197.645800  1032.8
# ...
